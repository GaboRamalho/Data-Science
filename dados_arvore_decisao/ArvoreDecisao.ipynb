# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tbl_cliente = pd.read_csv('/content/1_cliente.csv')
tbl_localizacao = pd.read_csv('/content/2_geolocalizacao.csv')
tbl_pedido = pd.read_csv('/content/3_pedido.csv')
tbl_pagamento = pd.read_csv('/content/4_pagamento.csv')
tbl_review = pd.read_csv('/content/5_review_clientes.csv')
tbl_entrega_pedido = pd.read_csv('/content/6_entrega_pedido.csv')
tbl_descricao_produto = pd.read_csv('/content/7_descricao_produto.csv')
tbl_vendedor = pd.read_csv('/content/8_vendedor.csv')
tbl_categoria_traduzido = pd.read_csv('/content/9_categoria_traduzido.csv')

# %%
tbl_cliente.head(1-2)
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99435  7fe2e80252a9ea476f950ae8f85b0f8f  4b5820135d360a45552b5163835b1d89
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
tbl_localizacao.head(1-2)
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000157                        99950       -28.068864       -52.012964
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
tbl_pedido.head(1-2)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112644  fffbee3b5462987e66fb49b1c5411df2              1
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
tbl_pagamento.head(1-2)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103880  7159096c5aa9be77f7f0c26c01ee9793                   1  credit_card
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
#
#         payment_installments  payment_value
# ...

# %%
tbl_review.head(1-2)
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title  \
# ...

# %%
tbl_entrega_pedido.head(1-2)
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99435  880675dff2150932f1601e1c07eadeeb  47cd45a6ac7b9fb16537df2ccffeb5ac
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
tbl_descricao_produto.head(1-2)
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32945  c4e71b64511b959455e2107fe7859020              utilidades_domesticas
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
#
# ...

# %%
tbl_vendedor.head(1-2)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3089  f1fdf2d13186575751aa25876536d85c                    5314
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
tbl_categoria_traduzido.head(1-2)
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 65                   dvds_blu_ray                  dvds_blu_ray
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
#
# [70 rows x 2 columns]

# %%
dados = tbl_cliente.merge(tbl_entrega_pedido).merge(tbl_pedido).merge(tbl_pagamento).merge(tbl_review).merge(tbl_vendedor)

# %%
dados.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 2  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 3  4c06b42fbf7b97ab10779cda5549cd1c  07d190f123147d9e89d4b922543d7948
# 4  8276de07ef25225d412b8462d73f8664  332cf4e83e16004ba7dca932ce82475b
#
#    customer_zip_code_prefix    customer_city customer_state  \
# 0                     14409           franca             SP
# 1                      1151        sao paulo             SP
# 2                      8775  mogi das cruzes             SP
# 3                     65075         sao luis             MA
# 4                     90010     porto alegre             RS
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# ...

# %%
dados.shape
# Out:
# (117329, 31)

# %%
dados.isnull().sum()
# Out:
# customer_id                           0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_id                              0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1235
# order_delivered_customer_date      2471
# order_estimated_delivery_date         0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# ...

# %%
dados.isna().sum()
# Out:
# customer_id                           0
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# order_id                              0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1235
# order_delivered_customer_date      2471
# order_estimated_delivery_date         0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# ...

# %%
df_ = dados.copy()

# %%
dados.columns.tolist()
# Out:
# ['customer_id',
#  'customer_unique_id',
#  'customer_zip_code_prefix',
#  'customer_city',
#  'customer_state',
#  'order_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'shipping_limit_date',
#  'price',
#  'freight_value',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value',
#  'review_id',
#  'review_score',
#  'review_comment_title',
#  'review_comment_message',
#  'review_creation_date',
#  'review_answer_timestamp',
#  'seller_zip_code_prefix',
#  'seller_city',
#  'seller_state']

# %%
dataframe = dados.drop(columns=["customer_unique_id",
                                "customer_city",
                                "customer_state",
                                "order_status",
                                "order_purchase_timestamp",
                                "order_approved_at",
                                "order_delivered_carrier_date",
                                "order_delivered_customer_date",
                                "order_estimated_delivery_date",
                                "shipping_limit_date",
                                "review_creation_date",
                                "review_answer_timestamp",
                                "seller_city",
                                "seller_state",
                                "review_comment_title",
                                "review_comment_message"])

# %%
dataframe.shape
# Out:
# (117329, 15)

# %%
dataframe.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1  4e7b3e00288586ebd08712fdd0374a03                      1151
# 2  b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 3  4c06b42fbf7b97ab10779cda5549cd1c                     65075
# 4  8276de07ef25225d412b8462d73f8664                     90010
#
#                            order_id  order_item_id  \
# 0  00e7ee1b050b8499577073aeb2a297a1              1
# 1  b2059ed67ce144a36e2aa97d2c9e9ad2              1
# 2  951670f92359f4fe4a63112aa7306eba              1
# 3  997fd4b37386d10b57d4ac8cdec011a6              1
# 4  b63fff1ef8b6201df68bb611ee41129e              1
#
#                          product_id                         seller_id   price  \
# 0  a9516a079e37a9c9c36b9b78b10169e8  7c67e1448b00f6e969d365cea6b010ab  124.99
# 1  bd07b66896d6f1494f5b86251848ced7  7c67e1448b00f6e969d365cea6b010ab  139.94
# ...

# %%
for coluna in dataframe:
  dataframe[coluna] = (np.array(dataframe[coluna]))

# %%
dataframe.columns.tolist()
# Out:
# ['customer_id',
#  'customer_zip_code_prefix',
#  'order_id',
#  'order_item_id',
#  'product_id',
#  'seller_id',
#  'price',
#  'freight_value',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value',
#  'review_id',
#  'review_score',
#  'seller_zip_code_prefix']

# %%
dataframe.columns = [
    "cliente",
    "cepcliente",
    "pedido",
    "idpedido",
    "produto",
    "vendedor",
    "preco_produto",
    "frete",
    "parcelas",
    "tipopagamento",
    "prestações",
    "valorfinal",
    "review",
    "score",
    "cepvendedor"
]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117329 entries, 0 to 117328
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   cliente        117329 non-null  object
#  1   cepcliente     117329 non-null  int64
#  2   pedido         117329 non-null  object
#  3   idpedido       117329 non-null  int64
#  4   produto        117329 non-null  object
#  5   vendedor       117329 non-null  object
#  6   preco_produto  117329 non-null  float64
#  7   frete          117329 non-null  float64
#  8   parcelas       117329 non-null  int64
#  9   tipopagamento  117329 non-null  object
#  10  prestações     117329 non-null  int64
#  11  valorfinal     117329 non-null  float64
#  12  review         117329 non-null  object
#  13  score          117329 non-null  int64
#  14  cepvendedor    117329 non-null  int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 14.3+ MB

# %%
dataframe.groupby( by='cliente').size()
# Out:
# cliente
# 00012a2ce6f8dcda20d059ce98491703    1
# 000161a058600d5901f007fab4c27140    1
# 0001fd6190edaaf884bcaf3d49edf079    1
# 0002414f95344307404f0ace7a26f1d5    1
# 000379cdec625522490c315e70c7a9fb    1
#                                    ..
# fffcb937e9dd47a13f05ecb8290f4d3e    1
# fffecc9f79fd8c764f843e9951b11341    3
# fffeda5b6d849fbd39689bb92087f431    1
# ffff42319e9b2d713724ae527742af25    1
# ffffa3172527f765de70084a7e53aae8    2
# Length: 97916, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = dataframe.copy()

# %%
df['cliente'] = df['cliente'].str.replace(r'\D', '')
df['pedido'] = df['pedido'].str.replace(r'\D', '')
df['produto'] = df['produto'].str.replace(r'\D', '')
df['vendedor'] = df['vendedor'].str.replace(r'\D', '')
df['review'] = df['review'].str.replace(r'\D', '')
df
# Out:
# <ipython-input-33-8f854d6524aa>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cliente'] = df['cliente'].str.replace(r'\D', '')
# <ipython-input-33-8f854d6524aa>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['pedido'] = df['pedido'].str.replace(r'\D', '')
# <ipython-input-33-8f854d6524aa>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['produto'] = df['produto'].str.replace(r'\D', '')
# <ipython-input-33-8f854d6524aa>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['vendedor'] = df['vendedor'].str.replace(r'\D', '')
# <ipython-input-33-8f854d6524aa>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review'] = df['review'].str.replace(r'\D', '')
# ...

# %%
result_df = pd.get_dummies(df, columns = ["tipopagamento"])

# %%
reserva = result_df.copy()
reserva
# Out:
#                          cliente  cepcliente                      pedido  \
# 0             068999211881720087       14409      0071050849957707322971
# 1         4730028858608712037403        1151          205967144362972992
# 2          260275510952946358123        8775      9516709235944631127306
# 3             406427971077955491       65075         9974373861057480116
# 4       827607252254128462738664       90010          631862016861141129
# ...                          ...         ...                         ...
# 117324          1075167500095617       39920  49462463110524497277085909
# 117325       0671403498200452602        7231         7331435643056154391
# 117326  908572770808078332363658       76400        76905458869336527267
# 117327     108322995705926071768       37610      5162460589765251860206
# 117328     108322995705926071768       37610      5162460589765251860206
#
#         idpedido                   produto                   vendedor  \
# ...

# %%
reserva = reserva.drop(reserva[reserva.score > 3].index)
reserva
# Out:
#                          cliente  cepcliente                   pedido  \
# 3             406427971077955491       65075      9974373861057480116
# 7         0372810041857927016263       21010    369525670169482825831
# 18             45800571938861445       13485      3793048208056190003
# 19          19530467435951219042       20920  54813422788333035171945
# 21             52814168460899591       36091       532771277634465595
# ...                          ...         ...                      ...
# 117320  049671902463228846651580        4929     93358729701080188455
# 117323     211018165721598633401       18650          357035504504584
# 117325       0671403498200452602        7231      7331435643056154391
# 117327     108322995705926071768       37610   5162460589765251860206
# 117328     108322995705926071768       37610   5162460589765251860206
#
#         idpedido                   produto                 vendedor  \
# ...
